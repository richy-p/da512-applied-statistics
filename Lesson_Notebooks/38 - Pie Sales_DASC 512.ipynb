# %% [markdown]
# # DASC 512 - Week 8 - Regression Examples

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.graphics.api as smg
import statsmodels.formula.api as smf

sns.set_style('darkgrid')

# %% [markdown]
# ## Pie Sales

# %%
pie = pd.read_csv('pie.csv')

# %%
pie.head()
# Out:
#    Qsales  Price  Advert  CompPrice  Income  2Income  Popul  Time  Year  \
# 0   26000    550    10.0        375    41.5       33   2300     8  1999
# 1   25000    600     7.5        375    40.5       28   2300     7  1999
# 2   24000    575    10.0        375    40.0       36   2250     6  1999
# 3   25000    575     5.0        400    39.5       29   2250     5  1999
# 4   27500    525    10.0        400    39.5       29   2200     4  1998
#
#    Quarter         City
# 0        4  Atlanta, GA
# 1        3  Atlanta, GA
# 2        2  Atlanta, GA
# 3        1  Atlanta, GA
# 4        4  Atlanta, GA

# %%
pie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Qsales     48 non-null     int64
#  1   Price      48 non-null     int64
#  2   Advert     48 non-null     float64
#  3   CompPrice  48 non-null     int64
#  4   Income     48 non-null     float64
#  5   2Income    48 non-null     int64
#  6   Popul      48 non-null     int64
#  7   Time       48 non-null     int64
#  8   Year       48 non-null     int64
#  9   Quarter    48 non-null     int64
#  10  City       48 non-null     object
# dtypes: float64(2), int64(8), object(1)
# memory usage: 4.2+ KB

# %%
pie.describe()
# Out:
#              Qsales       Price     Advert   CompPrice     Income    2Income  \
# count     48.000000   48.000000  48.000000   48.000000  48.000000  48.000000
# mean   25166.666667  579.166667   7.229167  386.458333  41.625000  28.562500
# std     4899.341394   32.752023   3.544487   30.491686   4.305489   5.086094
# min    15000.000000  500.000000   2.500000  325.000000  34.000000  20.000000
# 25%    22500.000000  550.000000   5.000000  375.000000  39.000000  24.000000
# 50%    25000.000000  575.000000   5.000000  387.500000  42.500000  29.000000
# 75%    27500.000000  600.000000  10.000000  400.000000  45.125000  33.000000
# max    34000.000000  625.000000  15.000000  450.000000  47.500000  38.000000
#
#              Popul       Time         Year    Quarter
# count    48.000000  48.000000    48.000000  48.000000
# mean   2421.666667   4.500000  1998.500000   2.500000
# std    2202.911597   2.315535     0.505291   1.129865
# min     480.000000   1.000000  1998.000000   1.000000
# ...

# %% [markdown]
# ### Hypothesize Model

# %%
sns.pairplot(pie[['Time','Year','Quarter']], height=1.5)
plt.show()

# %% [markdown]
# We can see redundant information here. Time is a number from 1-8, seemingly defined as Q1 1998 to Q4 1999. Quarter is a categorical variable that we may be interested in because it could uncover seasonal variations.
#
# I may also be interested in if CompPrice, Income, and 2Income are redundant.

# %%
pie['City'].value_counts()
# Out:
# Atlanta, GA           8
# Baltimore, MD         8
# Chicago, IL           8
# Denver, CO            8
# Erie, PA              8
# Ft. Lauderdale, FL    8
# Name: City, dtype: int64

# %%
sns.pairplot(pie[['CompPrice','Income','2Income']], height=1.5,
            kind='reg', markers='.')
plt.show()

# %% [markdown]
# They don't appear to be. Something we haven't discussed yet is a correlation matrix and heatmap. It can be a good tool for model building.

# %%
pie.corr()
# Out:
#              Qsales     Price    Advert  CompPrice    Income   2Income  \
# Qsales     1.000000 -0.306073  0.636702   0.364368  0.886859  0.216877
# Price     -0.306073  1.000000 -0.347465   0.017754 -0.079214 -0.158061
# Advert     0.636702 -0.347465  1.000000   0.063776  0.556462  0.050528
# CompPrice  0.364368  0.017754  0.063776   1.000000  0.191443 -0.172779
# Income     0.886859 -0.079214  0.556462   0.191443  1.000000  0.284320
# 2Income    0.216877 -0.158061  0.050528  -0.172779  0.284320  1.000000
# Popul      0.405932 -0.040978  0.193725  -0.033827  0.424955  0.253932
# Time       0.209116  0.112221  0.055736   0.022601  0.123782  0.215891
# Year       0.141810  0.192847  0.047519   0.103572  0.102690  0.202835
# Quarter    0.174884 -0.114992  0.029220  -0.138956  0.069980  0.079603
#
#               Popul      Time          Year       Quarter
# Qsales     0.405932  0.209116  1.418099e-01  1.748836e-01
# Price     -0.040978  0.112221  1.928473e-01 -1.149919e-01
# ...

# %%
fig, ax = plt.subplots(figsize=(3,3))
sns.heatmap(pie.corr(), vmin=-1, vmax=1, cmap='coolwarm',square=True, ax=ax)
plt.show()

# %% [markdown]
# Because Advert is correlated with both Income and Price, let's leave it out for now. We'll still include Price, CompPrice, Income, and Quarter.

# %%
formula = 'Qsales ~ Price + CompPrice + Income + C(Quarter)'
pmodel = smf.ols(formula, data=pie).fit()
pmodel.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                OLS                Adj. R-squared:       0.897
# Dependent Variable:   Qsales             AIC:                  849.4591
# Date:                 2022-11-21 11:04   BIC:                  862.5575
# No. Observations:     48                 Log-Likelihood:       -417.73
# Df Model:             6                  F-statistic:          68.88
# Df Residuals:         41                 Prob (F-statistic):   7.81e-20
# R-squared:            0.910              Scale:                2.4834e+06
# -------------------------------------------------------------------------
#                   Coef.     Std.Err.    t    P>|t|     [0.025     0.975]
# -------------------------------------------------------------------------
# Intercept       -9798.7587 5501.5830 -1.7811 0.0823 -20909.4309 1311.9136
# C(Quarter)[T.2]  -179.4371  644.4579 -0.2784 0.7821  -1480.9463 1122.0721
# ...

# %% [markdown]
# Pretty good. Everything looks highly significant. Let's try adding Advert back in.

# %%
formula = 'Qsales ~ Price + CompPrice + Income + C(Quarter) + Advert'
pmodel = smf.ols(formula, data=pie).fit()
pmodel.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                      Results: Ordinary least squares
# ...
# Model:                 OLS                Adj. R-squared:       0.905
# Dependent Variable:    Qsales             AIC:                  846.3803
# Date:                  2022-11-21 11:04   BIC:                  861.3499
# No. Observations:      48                 Log-Likelihood:       -415.19
# Df Model:              7                  F-statistic:          64.67
# Df Residuals:          40                 Prob (F-statistic):   8.40e-20
# R-squared:             0.919              Scale:                2.2899e+06
# --------------------------------------------------------------------------
#                    Coef.     Std.Err.    t    P>|t|     [0.025     0.975]
# --------------------------------------------------------------------------
# Intercept       -11250.7507 5327.4263 -2.1119 0.0410 -22017.8809 -483.6204
# ...

# %% [markdown]
# That still seems to have improved the model. Let's look at the residuals.

# %%
# Plot Residuals
resid = pmodel.resid
pred = pmodel.fittedvalues

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.scatterplot(x=pred, y=resid, ax=ax)
ax.set_title('Residuals plot')
ax.set_ylabel('Residual (Error)')
ax.set_xlabel('Predicted Sales')
fig.tight_layout()
plt.axhline(y=0, color='darkorchid', ls='--')
plt.show()

# %% [markdown]
# ### LOWESS - Locally Weighted Scatterplot Smoothing

# %% [markdown]
# Allow me to introduce another function that we can use to test these assumptions graphically. This displays a smoothed line that fits the residuals --- essentially a high-order polynomial model. It will show any localized areas of non-constant mean or variance (perhaps to a fault). Don't expect the plots to be perfect.
#
# Feel free to copy this function and use it in your homework and/or projects. You can refer to the line in your narrative as a LOWESS fit line.

# %%
def linearity_test(model, y):
    '''
    Function for visually inspecting the assumption of linearity in a linear regression model.
    It plots observed vs. predicted values and residuals vs. predicted values.
    It uses Locally Weighted Scatterplot Smoothing (LOWESS) to fit a model. 
    
    Args:
    * model - fitted OLS model from statsmodels
    * y - observed values
    '''
    pred = model.fittedvalues
    influence = model.get_influence()
    resid_std = influence.resid_studentized_internal
    
    fig, ax = plt.subplots(1,2, figsize=(7.5,3.5))
    
    sns.regplot(x=pred, y=y, lowess=True, ax=ax[0], line_kws={'color':'darkorchid'})
    # I've added the ideal line (y=yhat) for comparison
    sns.lineplot(x=[min(pred), max(pred)], y=[min(pred), max(pred)], 
                 ax=ax[0], color='red', ls=':')
    ax[0].set_title('Observed vs. Predicted Values')
    ax[0].set_xlabel('Predicted')
    ax[0].set_ylabel('Observed')
    
    sns.regplot(x=pred, y=resid_std, lowess=True, ax=ax[1], line_kws={'color':'darkorchid'})
    # I've added the ideal line (y=0) for comparison
    sns.lineplot(x=[min(pred), max(pred)], y=[0,0], ax=ax[1], color='red', ls=':')
    ax[1].set_title('Residuals vs. Predicted Values')
    ax[1].set_xlabel('Predicted')
    ax[1].set_ylabel('Standardized Residual')
    
    return fig, ax

# %%
fig, ax = linearity_test(pmodel, pie['Qsales'])
plt.show()

# %% [markdown]
# No major patterns exist that jump out. There may be some non-constant mean and some outliers between 25000-30000, but they aren't major. That's ok.

# %%
sns.displot(resid, kde=True, bins=5, aspect=2, height=3)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3,3))
smg.qqplot(resid, fit=True, line='45', ax=ax)
plt.show()

# %%
stats.shapiro(resid)
# Out:
# ShapiroResult(statistic=0.96501225233078, pvalue=0.1607760637998581)

# %% [markdown]
# Normality looks ok. Let's see if the multicollinearity we were concerned with earlier gave us large VIFs.

# %%
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor
y, X = dmatrices(formula, data=pie, return_type='dataframe')
vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(X.values,ii) for ii in range(X.shape[1])]
vif['Feature'] = X.columns
vif
# Out:
#           VIF          Feature
# 0  594.912068        Intercept
# 1    1.509622  C(Quarter)[T.2]
# 2    1.664010  C(Quarter)[T.3]
# 3    1.547569  C(Quarter)[T.4]
# 4    1.203216            Price
# 5    1.161887        CompPrice
# 6    1.572647           Income
# 7    1.809909           Advert

# %% [markdown]
# Not too bad, nothing to be concerned with. Now let's look at outliers and influence points.

# %%
influence = pmodel.get_influence()
resid_z = influence.resid_studentized_internal
resid_student = influence.resid_studentized_external

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.scatterplot(x=pred, y=resid_z, ax=ax)
ax.set_title('Standardized Residuals Plot')
ax.set_ylabel('Standardized Residual (Error)')
ax.set_xlabel('Predicted Sales')
fig.tight_layout()
plt.axhline(y=0, color='darkorchid', ls=':')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
sns.scatterplot(x=pred, y=resid_student, ax=ax)
ax.set_title('Studentized Residuals Plot')
ax.set_ylabel('Studentized Residual (Error)')
ax.set_xlabel('Predicted Sales')
fig.tight_layout()
plt.axhline(y=0, color='darkorchid', ls=':')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,5))
smg.influence_plot(pmodel, ax=ax)
plt.show()

# %% [markdown]
# This does highlight a couple of influence points, although they aren't too far from the main masses of points. Let's look at them.

# %%
pie.loc[[19,22]]
# Out:
#     Qsales  Price  Advert  CompPrice  Income  2Income  Popul  Time  Year  \
# 19   22500    600    10.0        350    44.5       22   7150     5  1999
# 22   25000    600     5.0        450    44.5       36   7100     2  1998
#
#     Quarter         City
# 19        1  Chicago, IL
# 22        2  Chicago, IL

# %%
fig, ax = plt.subplots(figsize=(5,5))
sns.scatterplot(x=pred, y=pie['Qsales'])
sns.scatterplot(x=pred[[19,22]], y=pie['Qsales'][[19,22]], color='red')
sns.lineplot(x=pred,y=pred)
plt.show()

# %% [markdown]
# These two data points from Chicago may be worth looking into more to see why they had lower than expected sales. I know that January 1999 was a huge North American blizzard, so that may explain one of the points.

# %% [markdown]
# # See you next time!
# For this week, I'll be splitting my Jupyter notebooks up by lesson. Each one is very self-contained, so that makes more sense this week.
